# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
data = pd.read_csv("./RestaurantUserprofile.csv",low_memory=False)

# %%
data.head()
# Out:
#   userID   latitude   longitude smoker     drink_level dress_preference  \
# 0  U1001  22.139997 -100.978803  false      abstemious         informal
# 1  U1002  22.150087 -100.983325  false      abstemious         informal
# 2  U1003  22.119847 -100.946527  false  social drinker           formal
# 3  U1004  18.867000  -99.183000  false      abstemious         informal
# 4  U1005  22.183477 -100.959891  false      abstemious    no preference
#
#   ambience transport marital_status        hijos  birth_year    interest  \
# 0   family   on foot         single  independent        1989     variety
# 1   family    public         single  independent        1990  technology
# 2   family    public         single  independent        1989        none
# 3   family    public         single  independent        1940     variety
# 4   family    public         single  independent        1992        none
#
#            personality  religion      activity  color  weight  budget  height
# 0    thrifty-protector      none       student  black      69  medium    1.77
# 1  hunter-ostentatious  Catholic       student    red      40     low    1.87
# 2          hard-worker  Catholic       student   blue      60     low    1.69
# 3          hard-worker      none  professional  green      44  medium    1.53
# 4    thrifty-protector  Catholic       student  black      65  medium    1.69

# %%
data.columns
# Out:
# Index(['userID', 'latitude', 'longitude', 'smoker', 'drink_level',
#        'dress_preference', 'ambience', 'transport', 'marital_status', 'hijos',
#        'birth_year', 'interest', 'personality', 'religion', 'activity',
#        'color', 'weight', 'budget', 'height'],
#       dtype='object')

# %%
data_modyfied = data.replace('?',np.nan)
data_modyfied = data_modyfied.replace('none',np.nan)
#modifide qustion mark with nan value

# %%
data_modyfied.tail(20)
# Out:
#     userID   latitude   longitude smoker     drink_level dress_preference  \
# 118  U1119  18.964790  -99.260017  false      abstemious           formal
# 119  U1120  22.121857 -100.904279  false      abstemious         informal
# 120  U1121  18.871674  -99.183253  false  social drinker    no preference
# 121  U1122  22.169601 -100.991821    NaN      abstemious              NaN
# 122  U1123  23.753112  -99.168567  false      abstemious         informal
# 123  U1124  22.137072 -100.918865  false  casual drinker         informal
# 124  U1125  22.192040 -100.956935  false  casual drinker           formal
# 125  U1126  22.154210 -100.942233  false  casual drinker           formal
# 126  U1127  18.943935  -99.206532  false      abstemious    no preference
# 127  U1128  22.187236 -100.994213  false  casual drinker    no preference
# 128  U1129  23.728798  -99.134047  false  casual drinker    no preference
# 129  U1130  23.733000  -99.133000    NaN      abstemious              NaN
# 130  U1131  22.138245 -100.910948   true  social drinker    no preference
# 131  U1132  22.150000 -100.983000  false  casual drinker         informal
# 132  U1133  18.886698  -99.114979  false      abstemious    no preference
# 133  U1134  22.149654 -100.998610  false  casual drinker    no preference
# 134  U1135  22.170396 -100.949936  false  casual drinker         informal
# 135  U1136  22.149607 -100.997235   true  social drinker    no preference
# 136  U1137  22.144803 -100.944623  false  social drinker           formal
# 137  U1138  22.152884 -100.939663  false  social drinker           formal
#
#      ambience  transport marital_status        hijos  birth_year  \
# 118    family     public         single  independent        1992
# 119   friends     public         single  independent        1930
# 120    family     public        married  independent        1987
# 121       NaN        NaN            NaN          NaN        1930
# 122    family        NaN         single  independent        1987
# 123   friends     public         single  independent        1991
# 124   friends     public         single  independent        1990
# 125   friends    on foot         single  independent        1990
# 126  solitary     public         single  independent        1992
# 127   friends     public         single  independent        1986
# 128   friends     public         single  independent        1989
# 129       NaN        NaN            NaN          NaN        1989
# 130   friends  car owner        married         kids        1990
# 131  solitary     public         single          NaN        1991
# 132    family  car owner         single  independent        1991
# 133    family     public         single  independent        1991
# 134    family    on foot         single         kids        1988
# 135   friends  car owner         single  independent        1990
# 136    family     public         single  independent        1989
# 137   friends     public         single  independent        1991
#
#          interest          personality  religion       activity   color  \
# 118  eco-friendly    thrifty-protector  Catholic        student    blue
# 119       variety          hard-worker       NaN        student   green
# 120       variety    thrifty-protector  Catholic  working-class   black
# 121           NaN          hard-worker       NaN            NaN  yellow
# 122    technology          hard-worker  Catholic        student   green
# 123           NaN          hard-worker  Catholic        student    blue
# 124    technology          hard-worker  Catholic        student   white
# 125    technology          hard-worker  Catholic        student  purple
# 126       variety          hard-worker  Catholic        student   black
# 127       variety    thrifty-protector  Catholic        student     red
# 128       variety    thrifty-protector       NaN        student  purple
# 129           NaN          hard-worker       NaN            NaN  yellow
# 130  eco-friendly          hard-worker       NaN        student   black
# 131           NaN          hard-worker       NaN        student    blue
# 132           NaN          hard-worker       NaN        student  orange
# 133       variety          hard-worker  Catholic        student   black
# 134       variety  hunter-ostentatious  Catholic        student  purple
# 135         retro    thrifty-protector  Catholic        student   black
# 136  eco-friendly          hard-worker  Catholic        student    blue
# 137       variety    thrifty-protector       NaN        student    blue
#
#      weight  budget  height
# 118      68  medium    1.68
# 119      47     low    1.57
# 120      90  medium    1.60
# 121      40     NaN    1.20
# 122     110  medium    1.75
# 123      51     low    1.20
# 124      57     low    1.67
# 125      65     low    1.63
# 126      65     low    1.76
# 127      66     low    1.72
# 128      69     low    1.69
# 129      40     NaN    1.20
# 130      90  medium    1.80
# 131      55     NaN    1.60
# 132      60  medium    1.57
# 133      52  medium    1.65
# 134      66     low    1.54
# 135      50     low    1.60
# 136      72     low    1.78
# 137      54  medium    1.55

# %%
data_modyfied.isna().any()
# Out:
# userID              False
# latitude            False
# longitude           False
# smoker               True
# drink_level         False
# dress_preference     True
# ambience             True
# transport            True
# marital_status       True
# hijos                True
# birth_year          False
# interest             True
# personality         False
# religion             True
# activity             True
# color               False
# weight              False
# budget               True
# height              False
# dtype: bool

# %%
data_modyfied = data_modyfied.loc[:, data_modyfied.isnull().any()]
data_modyfied
# Out:
#     smoker dress_preference ambience  transport marital_status        hijos  \
# 0    false         informal   family    on foot         single  independent
# 1    false         informal   family     public         single  independent
# 2    false           formal   family     public         single  independent
# 3    false         informal   family     public         single  independent
# 4    false    no preference   family     public         single  independent
# ..     ...              ...      ...        ...            ...          ...
# 133  false    no preference   family     public         single  independent
# 134  false         informal   family    on foot         single         kids
# 135   true    no preference  friends  car owner         single  independent
# 136  false           formal   family     public         single  independent
# 137  false           formal  friends     public         single  independent
#
#          interest  religion      activity  budget
# 0         variety       NaN       student  medium
# 1      technology  Catholic       student     low
# 2             NaN  Catholic       student     low
# 3         variety       NaN  professional  medium
# 4             NaN  Catholic       student  medium
# ..            ...       ...           ...     ...
# 133       variety  Catholic       student  medium
# 134       variety  Catholic       student     low
# 135         retro  Catholic       student     low
# 136  eco-friendly  Catholic       student     low
# 137       variety       NaN       student  medium
#
# [138 rows x 10 columns]

# %%
# all miss value are object(catagroical data)
data_modyfied.dtypes
# Out:
# smoker              object
# dress_preference    object
# ambience            object
# transport           object
# marital_status      object
# hijos               object
# interest            object
# religion            object
# activity            object
# budget              object
# dtype: object

# %%
data_modyfied = data_modyfied.fillna(data_modyfied.mode().iloc[-1])
data_modyfied.tail(10)
data=data.fillna(data_modyfied)

# %%
for i in data_modyfied.columns:
    print(i,data_modyfied[i].unique())
#we dont have inconsistence data
# Out:
# smoker ['false' 'true']
# dress_preference ['informal' 'formal' 'no preference' 'elegant']
# ambience ['family' 'friends' 'solitary']
# transport ['on foot' 'public' 'car owner']
# marital_status ['single' 'married' 'widow']
# hijos ['independent' 'kids' 'dependent']
# interest ['variety' 'technology' 'retro' 'eco-friendly']
# religion ['Catholic' 'Christian' 'Mormon' 'Jewish']
# activity ['student' 'professional' 'unemployed' 'working-class']
# budget ['medium' 'low' 'high']

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

numerical=data.select_dtypes(include=numerics)
#numerical.columns ['latitude', 'longitude', 'birth_year', 'weight', 'height']
numerical=numerical.iloc[:,2:]
numerical
# Out:
#      birth_year  weight  height
# 0          1989      69    1.77
# 1          1990      40    1.87
# 2          1989      60    1.69
# 3          1940      44    1.53
# 4          1992      65    1.69
# ..          ...     ...     ...
# 133        1991      52    1.65
# 134        1988      66    1.54
# 135        1990      50    1.60
# 136        1989      72    1.78
# 137        1991      54    1.55
#
# [138 rows x 3 columns]

# %%
# from geopy.geocoders import Nominatim
# geolocator = Nominatim(user_agent="geoapiExercises")

# def city_state_country(row):
#     coord = f"{row['latitude']}, {row['longitude']}"
#     location = geolocator.reverse(coord, exactly_one=True)
#     address = location.raw['address']
#     city = address.get('city', '')
#     state = address.get('state', '')
#     country = address.get('country', '')
#     row['city'] = city
#     row['state'] = state
#     row['country'] = country
#     return row
    
# data=data.apply(city_state_country, axis=1)

# %%
# fig, ax = plt.subplots(figsize = (12, 7))
# corr = data.corr()
# #sn.heatmap(corr, annot = True)
# sn.heatmap(corr, annot=True, fmt=".1f")

# %%
feature_binned=numerical.sort_values(by=['birth_year', 'weight', 'height'])
binn=(feature_binned.birth_year.max()-feature_binned.birth_year.min())/8


for bin_number in range(7):
    
    print(feature_binned.loc[feature_binned['birth_year']>(feature_binned.birth_year.min()+binn*(bin_number+1))])
    

#feature_binned.birth_year.value_counts()
# Out:
#      birth_year  weight  height
# 3          1940      44    1.53
# 41         1943      40    1.40
# 54         1952      70    1.66
# 73         1967      68    1.70
# 43         1969      85    1.73
# ..          ...     ...     ...
# 4          1992      65    1.69
# 126        1992      65    1.76
# 118        1992      68    1.68
# 109        1993      85    1.75
# 39         1994      73    1.64
#
# [131 rows x 3 columns]
#      birth_year  weight  height
# 54         1952      70    1.66
# 73         1967      68    1.70
# 43         1969      85    1.73
# 50         1979      74    1.76
# 82         1981      40    1.60
# ..          ...     ...     ...
# 4          1992      65    1.69
# 126        1992      65    1.76
# 118        1992      68    1.68
# 109        1993      85    1.75
# 39         1994      73    1.64
#
# [129 rows x 3 columns]
#      birth_year  weight  height
# 73         1967      68    1.70
# 43         1969      85    1.73
# 50         1979      74    1.76
# 82         1981      40    1.60
# 19         1982      40    1.68
# ..          ...     ...     ...
# 4          1992      65    1.69
# 126        1992      65    1.76
# 118        1992      68    1.68
# 109        1993      85    1.75
# 39         1994      73    1.64
#
# [128 rows x 3 columns]
#      birth_year  weight  height
# 73         1967      68    1.70
# 43         1969      85    1.73
# 50         1979      74    1.76
# 82         1981      40    1.60
# 19         1982      40    1.68
# ..          ...     ...     ...
# 4          1992      65    1.69
# 126        1992      65    1.76
# 118        1992      68    1.68
# 109        1993      85    1.75
# 39         1994      73    1.64
#
# [128 rows x 3 columns]
#      birth_year  weight  height
# 50         1979      74    1.76
# 82         1981      40    1.60
# 19         1982      40    1.68
# 116        1982      58    1.60
# 12         1982      80    1.75
# ..          ...     ...     ...
# 4          1992      65    1.69
# 126        1992      65    1.76
# 118        1992      68    1.68
# 109        1993      85    1.75
# 39         1994      73    1.64
#
# [126 rows x 3 columns]
#      birth_year  weight  height
# 50         1979      74    1.76
# 82         1981      40    1.60
# 19         1982      40    1.68
# 116        1982      58    1.60
# 12         1982      80    1.75
# ..          ...     ...     ...
# 4          1992      65    1.69
# 126        1992      65    1.76
# 118        1992      68    1.68
# 109        1993      85    1.75
# 39         1994      73    1.64
#
# [126 rows x 3 columns]
#      birth_year  weight  height
# 9          1987      40    1.67
# 115        1987      40    1.71
# 58         1987      57    1.69
# 117        1987      60    1.68
# 75         1987      65    1.71
# ..          ...     ...     ...
# 4          1992      65    1.69
# 126        1992      65    1.76
# 118        1992      68    1.68
# 109        1993      85    1.75
# 39         1994      73    1.64
#
# [110 rows x 3 columns]
